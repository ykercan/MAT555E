# %% [markdown]
# # Question 1
#
# Write a python function that returns $2\sin(x^2) + \ln(|x|) + 1$ for a given real number $x$.

# %%
def my_func(x):
    import math
    return (2*math.sin(x**2) + math.log(abs(x)) + 1)

# %% [markdown]
# # Question 2
#
# Write a python function that takes
#
# * A function `f(x)`
# * A pair of real numbers `(a,b)`
# * An integer `N`
#
# as input and returns the Riemann sum of `f(x)` on the interval `[a,b]` with `N` equal subdivisions.

# %%
def riemann_sum(f,a,b,n):
    '''
    Calculation of the Riemann sum.
    '''
    import math
    delta_x = (b-a)/n
    
    result = 0.5*f(a) + sum([f(a + i*w) for i in range(1,N)]) + 0.5*f(b)
    result *= w
    return result

# %%
riemann_sum(math.sin(pi),2,3,1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-97447e50a7f9> in <module>()
# ----> 1 riemann_sum(math.sin(pi),2,3,1000)
#
# NameError: name 'math' is not defined

# %% [markdown]
# # Question 3
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ as an array `xs`.
# * Add 0 at the beginning of the array, and 1.0 at the end.
# * Sort the array `xs` from smallest to the largest.
# * Calculate its discrete derivative `ys`, i.e. let $y_i = x_{i+1} - x_i$

# %%
import numpy as np
xs = np.random.uniform(0,1,100)
xs = np.insert(xs,0,0)
xs = np.append(xs,1)
xs.sort()

ys = []

for i in range(len(xs)):
    if i < 101:
        yi = xs[i+1]-xs[i]
        ys.append(yi)
    else:
        break

# %% [markdown]
# # Question 4
#
# * Pull 100 uniformly random numbers from the interval $[0,1]$ into an array `xs`.
# * Pull 100 random numbers from the Gaussion distribution with $\mu=0$ and $\sigma=1.0$ into an array `ys`.
# * Scatter plot `xs` against `ys` using `matplotlib`

# %%
import numpy as np
import matplotlib.pyplot as plt
xs = np.random.uniform(0,1,100)
ys = np.random.normal(0,1,100)
plt.scatter(xs,ys)
plt.show()

# %% [markdown]
# # Question 5
#
# Using the `numpy` library
#
# * Pull a random $100\times 100$ matrix
# * Calculate its 100-th power
# * Calculate its eigen-values
# * Calculate is [Singular Value Decomposition](https://numpy.org/doc/stable/reference/generated/numpy.linalg.svd.html)

# %%
import numpy as np
from numpy.linalg import matrix_power
from numpy import linalg as LA

mtx = np.random.rand(100,100)
mtx = matrix_power(mtx,100)
w,v = LA.eig(mtx)
u, s, vh = np.linalg.svd(mtx, full_matrices=True)

# %% [markdown]
# # Question 6
#
# * Pull the text of a novel by Dickens from the website of [Gutenberg Project](https://www.gutenberg.org/)
# * Remove all non-alphanumeric characters
# * Split the text into words and convert them into lower case
# * Count the number of distinct words in the  text
# * Count how many times each word occurs within the text

# %%
import pandas as pd
import urllib.request
import re

# df = pd.read_csv("https://www.gutenberg.org/files/1289/1289-0.txt", sep=" ")
# url="https://www.gutenberg.org/files/1289/1289-0.txt"
# data=pd.read_csv(url)

for line in urllib.request.urlopen("https://www.gutenberg.org/files/1289/1289-0.txt"):
    print(line)
    
for x in line:
    line.decode("utf-8") 
    print(x)
# re.sub(r'\W+', '', line)   

# mydata['text'] = mydata['text'].str.replace(r'[^\w\s]+', '')
# mydata = mydata.str.replace(r'[^\w\s]+', '')
# df.strings.str.replace('[^a-zA-Z0-9]', '')
# df.str.isalpha()

# df = df.to_string
# df.strings.str.replace('[^a-zA-Z0-9]', '')
# Out:
# b'\xef\xbb\xbfThe Project Gutenberg eBook, Three Ghost Stories, by Charles Dickens\r\n'
# b'\r\n'
# b'\r\n'
# b'This eBook is for the use of anyone anywhere at no cost and with\r\n'
# b'almost no restrictions whatsoever.  You may copy it, give it away or\r\n'
# b're-use it under the terms of the Project Gutenberg License included\r\n'
# b'with this eBook or online at www.gutenberg.org\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'Title: Three Ghost Stories\r\n'
# b'\r\n'
# b'\r\n'
# b'Author: Charles Dickens\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'Release Date: March 9, 2013  [eBook #1289]\r\n'
# b'[This file was first posted on April 5, 1998]\r\n'
# b'\r\n'
# b'Language: English\r\n'
# b'\r\n'
# b'Character set encoding: UTF-8\r\n'
# b'\r\n'
# b'\r\n'
# b'***START OF THE PROJECT GUTENBERG EBOOK THREE GHOST STORIES***\r\n'
# b'\r\n'
# b'\r\n'
# b'Transcribed from the 1894 Chapman and Hall edition of \xe2\x80\x9cChristmas Stories\xe2\x80\x9d\r\n'
# b'by David Price, email ccx074@pglaf.org\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'                           THREE GHOST STORIES\r\n'
# b'\r\n'
# b'\r\n'
# b'                            by Charles Dickens\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'CONTENTS\r\n'
# b'\r\n'
# b'The Haunted House             121\r\n'
# b'The Trial For Murder          303\r\n'
# b'The Signal-Man                312\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'THE HAUNTED HOUSE.\r\n'
# b'IN TWO CHAPTERS. {121}\r\n'
# b'\r\n'
# b'\r\n'
# b'                                 [1859.]\r\n'
# b'\r\n'
# b'\r\n'
# b'\r\n'
# b'THE MORTALS IN THE HOUSE.\r\n'
# b'\r\n'
# b'\r\n'
# b'UNDER none of the accredited ghostly circumstances, and environed by none\r\n'
# b'of the conventional ghostly surroundings, did I first make acquaintance\r\n'
# b'with the house which is the subject of this Christmas piece.  I saw it in\r\n'
# b'the daylight, with the sun upon it.  There was no wind, no rain, no\r\n'
# b'lightning, no thunder, no awful or unwonted circumstance, of any kind, to\r\n'
# b'heighten its effect.  More than that: I had come to it direct from a\r\n'
# b'railway station: it was not more than a mile distant from the railway\r\n'
# b'station; and, as I stood outside the house, looking back upon the way I\r\n'
# b'had come, I could see the goods train running smoothly along the\r\n'
# b'embankment in the valley.  I will not say that everything was utterly\r\n'
# b'commonplace, because I doubt if anything can be that, except to utterly\r\n'
# b'commonplace people\xe2\x80\x94and there my vanity steps in; but, I will take it on\r\n'
# b'myself to say that anybody might see the house as I saw it, any fine\r\n'
# b'autumn morning.\r\n'
# b'\r\n'
# b'The manner of my lighting on it was this.\r\n'
# b'\r\n'
# b'I was travelling towards London out of the North, intending to stop by\r\n'
# b'the way, to look at the house.  My health required a temporary residence\r\n'
# b'in the country; and a friend of mine who knew that, and who had happened\r\n'
# b'to drive past the house, had written to me to suggest it as a likely\r\n'
# b'place.  I had got into the train at midnight, and had fallen asleep, and\r\n'
# b'had woke up and had sat looking out of window at the brilliant Northern\r\n'
# b'Lights in the sky, and had fallen asleep again, and had woke up again to\r\n'
# b'find the night gone, with the usual discontented conviction on me that I\r\n'
# b'hadn\xe2\x80\x99t been to sleep at all;\xe2\x80\x94upon which question, in the first imbecility\r\n'
# b'of that condition, I am ashamed to believe that I would have done wager\r\n'
# b'by battle with the man who sat opposite me.  That opposite man had had,\r\n'
# b'through the night\xe2\x80\x94as that opposite man always has\xe2\x80\x94several legs too many,\r\n'
# b'and all of them too long.  In addition to this unreasonable conduct\r\n'
# b'(which was only to be expected of him), he had had a pencil and a\r\n'
# b'pocket-book, and had been perpetually listening and taking notes.  It had\r\n'
# b'appeared to me that these aggravating notes related to the jolts and\r\n'
# b'bumps of the carriage, and I should have resigned myself to his taking\r\n'
# b'them, under a general supposition that he was in the civil-engineering\r\n'
# b'way of life, if he had not sat staring straight over my head whenever he\r\n'
# b'listened.  He was a goggle-eyed gentleman of a perplexed aspect, and his\r\n'
# b'demeanour became unbearable.\r\n'
# b'\r\n'
# b'It was a cold, dead morning (the sun not being up yet), and when I had\r\n'
# b'out-watched the paling light of the fires of the iron country, and the\r\n'
# b'curtain of heavy smoke that hung at once between me and the stars and\r\n'
# b'between me and the day, I turned to my fellow-traveller and said:\r\n'
# b'\r\n'
# b'\xe2\x80\x9cI _beg_ your pardon, sir, but do you observe anything particular in me?\xe2\x80\x9d\r\n'
# b'For, really, he appeared to be taking down, either my travelling-cap or\r\n'
# b'my hair, with a minuteness that was a liberty.\r\n'
# b'\r\n'
# b'The goggle-eyed gentleman withdrew his eyes from behind me, as if the\r\n'
# b'back of the carriage were a hundred miles off, and said, with a lofty\r\n'
# b'look of compassion for my insignificance:\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIn you, sir?\xe2\x80\x94B.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cB, sir?\xe2\x80\x9d said I, growing warm.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cI have nothing to do with you, sir,\xe2\x80\x9d returned the gentleman; \xe2\x80\x9cpray let\r\n'
# b'me listen\xe2\x80\x94O.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'He enunciated this vowel after a pause, and noted it down.\r\n'
# b'\r\n'
# b'At first I was alarmed, for an Express lunatic and no communication with\r\n'
# b'the guard, is a serious position.  The thought came to my relief that the\r\n'
# b'gentleman might be what is popularly called a Rapper: one of a sect for\r\n'
# b'(some of) whom I have the highest respect, but whom I don\xe2\x80\x99t believe in.\r\n'
# b'I was going to ask him the question, when he took the bread out of my\r\n'
# b'mouth.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cYou will excuse me,\xe2\x80\x9d said the gentleman contemptuously, \xe2\x80\x9cif I am too\r\n'
# b'much in advance of common humanity to trouble myself at all about it.  I\r\n'
# b'have passed the night\xe2\x80\x94as indeed I pass the whole of my time now\xe2\x80\x94in\r\n'
# b'spiritual intercourse.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cO!\xe2\x80\x9d said I, somewhat snappishly.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cThe conferences of the night began,\xe2\x80\x9d continued the gentleman, turning\r\n'
# b'several leaves of his note-book, \xe2\x80\x9cwith this message: \xe2\x80\x98Evil communications\r\n'
# b'corrupt good manners.\xe2\x80\x99\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cSound,\xe2\x80\x9d said I; \xe2\x80\x9cbut, absolutely new?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cNew from spirits,\xe2\x80\x9d returned the gentleman.\r\n'
# b'\r\n'
# b'I could only repeat my rather snappish \xe2\x80\x9cO!\xe2\x80\x9d and ask if I might be\r\n'
# b'favoured with the last communication.\r\n'
# b'\r\n'
# b'\xe2\x80\x9c\xe2\x80\x98A bird in the hand,\xe2\x80\x99\xe2\x80\x9d said the gentleman, reading his last entry with\r\n'
# b'great solemnity, \xe2\x80\x9c\xe2\x80\x98is worth two in the Bosh.\xe2\x80\x99\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cTruly I am of the same opinion,\xe2\x80\x9d said I; \xe2\x80\x9cbut shouldn\xe2\x80\x99t it be Bush?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIt came to me, Bosh,\xe2\x80\x9d returned the gentleman.\r\n'
# b'\r\n'
# b'The gentleman then informed me that the spirit of Socrates had delivered\r\n'
# b'this special revelation in the course of the night.  \xe2\x80\x9cMy friend, I hope\r\n'
# b'you are pretty well.  There are two in this railway carriage.  How do you\r\n'
# b'do?  There are seventeen thousand four hundred and seventy-nine spirits\r\n'
# b'here, but you cannot see them.  Pythagoras is here.  He is not at liberty\r\n'
# b'to mention it, but hopes you like travelling.\xe2\x80\x9d  Galileo likewise had\r\n'
# b'dropped in, with this scientific intelligence.  \xe2\x80\x9cI am glad to see you,\r\n'
# b'_amico_.  _Come sta_?  Water will freeze when it is cold enough.\r\n'
# b'_Addio_!\xe2\x80\x9d  In the course of the night, also, the following phenomena had\r\n'
# b'occurred.  Bishop Butler had insisted on spelling his name, \xe2\x80\x9cBubler,\xe2\x80\x9d for\r\n'
# b'which offence against orthography and good manners he had been dismissed\r\n'
# b'as out of temper.  John Milton (suspected of wilful mystification) had\r\n'
# b'repudiated the authorship of Paradise Lost, and had introduced, as joint\r\n'
# b'authors of that poem, two Unknown gentlemen, respectively named Grungers\r\n'
# b'and Scadgingtone.  And Prince Arthur, nephew of King John of England, had\r\n'
# b'described himself as tolerably comfortable in the seventh circle, where\r\n'
# b'he was learning to paint on velvet, under the direction of Mrs. Trimmer\r\n'
# b'and Mary Queen of Scots.\r\n'
# b'\r\n'
# b'If this should meet the eye of the gentleman who favoured me with these\r\n'
# b'disclosures, I trust he will excuse my confessing that the sight of the\r\n'
# b'rising sun, and the contemplation of the magnificent Order of the vast\r\n'
# b'Universe, made me impatient of them.  In a word, I was so impatient of\r\n'
# b'them, that I was mightily glad to get out at the next station, and to\r\n'
# b'exchange these clouds and vapours for the free air of Heaven.\r\n'
# b'\r\n'
# b'By that time it was a beautiful morning.  As I walked away among such\r\n'
# b'leaves as had already fallen from the golden, brown, and russet trees;\r\n'
# b'and as I looked around me on the wonders of Creation, and thought of the\r\n'
# b'steady, unchanging, and harmonious laws by which they are sustained; the\r\n'
# b'gentleman\xe2\x80\x99s spiritual intercourse seemed to me as poor a piece of\r\n'
# b'journey-work as ever this world saw.  In which heathen state of mind, I\r\n'
# b'came within view of the house, and stopped to examine it attentively.\r\n'
# b'\r\n'
# b'It was a solitary house, standing in a sadly neglected garden: a pretty\r\n'
# b'even square of some two acres.  It was a house of about the time of\r\n'
# b'George the Second; as stiff, as cold, as formal, and in as bad taste, as\r\n'
# b'could possibly be desired by the most loyal admirer of the whole quartet\r\n'
# b'of Georges.  It was uninhabited, but had, within a year or two, been\r\n'
# b'cheaply repaired to render it habitable; I say cheaply, because the work\r\n'
# b'had been done in a surface manner, and was already decaying as to the\r\n'
# b'paint and plaster, though the colours were fresh.  A lop-sided board\r\n'
# b'drooped over the garden wall, announcing that it was \xe2\x80\x9cto let on very\r\n'
# b'reasonable terms, well furnished.\xe2\x80\x9d  It was much too closely and heavily\r\n'
# b'shadowed by trees, and, in particular, there were six tall poplars before\r\n'
# b'the front windows, which were excessively melancholy, and the site of\r\n'
# b'which had been extremely ill chosen.\r\n'
# b'\r\n'
# b'It was easy to see that it was an avoided house\xe2\x80\x94a house that was shunned\r\n'
# b'by the village, to which my eye was guided by a church spire some half a\r\n'
# b'mile off\xe2\x80\x94a house that nobody would take.  And the natural inference was,\r\n'
# b'that it had the reputation of being a haunted house.\r\n'
# b'\r\n'
# b'                       [Picture: The haunted house]\r\n'
# b'\r\n'
# b'No period within the four-and-twenty hours of day and night is so solemn\r\n'
# b'to me, as the early morning.  In the summer-time, I often rise very\r\n'
# b'early, and repair to my room to do a day\xe2\x80\x99s work before breakfast, and I\r\n'
# b'am always on those occasions deeply impressed by the stillness and\r\n'
# b'solitude around me.  Besides that there is something awful in the being\r\n'
# b'surrounded by familiar faces asleep\xe2\x80\x94in the knowledge that those who are\r\n'
# b'dearest to us and to whom we are dearest, are profoundly unconscious of\r\n'
# b'us, in an impassive state, anticipative of that mysterious condition to\r\n'
# b'which we are all tending\xe2\x80\x94the stopped life, the broken threads of\r\n'
# b'yesterday, the deserted seat, the closed book, the unfinished but\r\n'
# b'abandoned occupation, all are images of Death.  The tranquillity of the\r\n'
# b'hour is the tranquillity of Death.  The colour and the chill have the\r\n'
# b'same association.  Even a certain air that familiar household objects\r\n'
# b'take upon them when they first emerge from the shadows of the night into\r\n'
# b'the morning, of being newer, and as they used to be long ago, has its\r\n'
# b'counterpart in the subsidence of the worn face of maturity or age, in\r\n'
# b'death, into the old youthful look.  Moreover, I once saw the apparition\r\n'
# b'of my father, at this hour.  He was alive and well, and nothing ever came\r\n'
# b'of it, but I saw him in the daylight, sitting with his back towards me,\r\n'
# b'on a seat that stood beside my bed.  His head was resting on his hand,\r\n'
# b'and whether he was slumbering or grieving, I could not discern.  Amazed\r\n'
# b'to see him there, I sat up, moved my position, leaned out of bed, and\r\n'
# b'watched him.  As he did not move, I spoke to him more than once.  As he\r\n'
# b'did not move then, I became alarmed and laid my hand upon his shoulder,\r\n'
# b'as I thought\xe2\x80\x94and there was no such thing.\r\n'
# b'\r\n'
# b'For all these reasons, and for others less easily and briefly statable, I\r\n'
# b'find the early morning to be my most ghostly time.  Any house would be\r\n'
# b'more or less haunted, to me, in the early morning; and a haunted house\r\n'
# b'could scarcely address me to greater advantage than then.\r\n'
# b'\r\n'
# b'I walked on into the village, with the desertion of this house upon my\r\n'
# b'mind, and I found the landlord of the little inn, sanding his door-step.\r\n'
# b'I bespoke breakfast, and broached the subject of the house.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIs it haunted?\xe2\x80\x9d I asked.\r\n'
# b'\r\n'
# b'The landlord looked at me, shook his head, and answered, \xe2\x80\x9cI say nothing.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cThen it _is_ haunted?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWell!\xe2\x80\x9d cried the landlord, in an outburst of frankness that had the\r\n'
# b'appearance of desperation\xe2\x80\x94\xe2\x80\x9cI wouldn\xe2\x80\x99t sleep in it.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWhy not?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIf I wanted to have all the bells in a house ring, with nobody to ring\r\n'
# b'\xe2\x80\x99em; and all the doors in a house bang, with nobody to bang \xe2\x80\x99em; and all\r\n'
# b'sorts of feet treading about, with no feet there; why, then,\xe2\x80\x9d said the\r\n'
# b'landlord, \xe2\x80\x9cI\xe2\x80\x99d sleep in that house.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIs anything seen there?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'The landlord looked at me again, and then, with his former appearance of\r\n'
# b'desperation, called down his stable-yard for \xe2\x80\x9cIkey!\xe2\x80\x9d\r\n'
# b'\r\n'
# b'The call produced a high-shouldered young fellow, with a round red face,\r\n'
# b'a short crop of sandy hair, a very broad humorous mouth, a turned-up\r\n'
# b'nose, and a great sleeved waistcoat of purple bars, with mother-of-pearl\r\n'
# b'buttons, that seemed to be growing upon him, and to be in a fair way\xe2\x80\x94if\r\n'
# b'it were not pruned\xe2\x80\x94of covering his head and overunning his boots.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cThis gentleman wants to know,\xe2\x80\x9d said the landlord, \xe2\x80\x9cif anything\xe2\x80\x99s seen at\r\n'
# b'the Poplars.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9c\xe2\x80\x99Ooded woman with a howl,\xe2\x80\x9d said Ikey, in a state of great freshness.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cDo you mean a cry?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cI mean a bird, sir.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cA hooded woman with an owl.  Dear me!  Did you ever see her?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cI seen the howl.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cNever the woman?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cNot so plain as the howl, but they always keeps together.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cHas anybody ever seen the woman as plainly as the owl?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cLord bless you, sir!  Lots.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWho?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cLord bless you, sir!  Lots.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cThe general-dealer opposite, for instance, who is opening his shop?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cPerkins?  Bless you, Perkins wouldn\xe2\x80\x99t go a-nigh the place.  No!\xe2\x80\x9d\r\n'
# b'observed the young man, with considerable feeling; \xe2\x80\x9che an\xe2\x80\x99t overwise,\r\n'
# b'an\xe2\x80\x99t Perkins, but he an\xe2\x80\x99t such a fool as _that_.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'(Here, the landlord murmured his confidence in Perkins\xe2\x80\x99s knowing better.)\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWho is\xe2\x80\x94or who was\xe2\x80\x94the hooded woman with the owl?  Do you know?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWell!\xe2\x80\x9d said Ikey, holding up his cap with one hand while he scratched\r\n'
# b'his head with the other, \xe2\x80\x9cthey say, in general, that she was murdered,\r\n'
# b'and the howl he \xe2\x80\x99ooted the while.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'This very concise summary of the facts was all I could learn, except that\r\n'
# b'a young man, as hearty and likely a young man as ever I see, had been\r\n'
# b'took with fits and held down in \xe2\x80\x99em, after seeing the hooded woman.\r\n'
# b'Also, that a personage, dimly described as \xe2\x80\x9ca hold chap, a sort of\r\n'
# b'one-eyed tramp, answering to the name of Joby, unless you challenged him\r\n'
# b'as Greenwood, and then he said, \xe2\x80\x98Why not? and even if so, mind your own\r\n'
# b'business,\xe2\x80\x99\xe2\x80\x9d had encountered the hooded woman, a matter of five or six\r\n'
# b'times.  But, I was not materially assisted by these witnesses: inasmuch\r\n'
# b'as the first was in California, and the last was, as Ikey said (and he\r\n'
# b'was confirmed by the landlord), Anywheres.\r\n'
# b'\r\n'
# b'Now, although I regard with a hushed and solemn fear, the mysteries,\r\n'
# b'between which and this state of existence is interposed the barrier of\r\n'
# b'the great trial and change that fall on all the things that live; and\r\n'
# b'although I have not the audacity to pretend that I know anything of them;\r\n'
# b'I can no more reconcile the mere banging of doors, ringing of bells,\r\n'
# b'creaking of boards, and such-like insignificances, with the majestic\r\n'
# b'beauty and pervading analogy of all the Divine rules that I am permitted\r\n'
# b'to understand, than I had been able, a little while before, to yoke the\r\n'
# b'spiritual intercourse of my fellow-traveller to the chariot of the rising\r\n'
# b'sun.  Moreover, I had lived in two haunted houses\xe2\x80\x94both abroad.  In one of\r\n'
# b'these, an old Italian palace, which bore the reputation of being very\r\n'
# b'badly haunted indeed, and which had recently been twice abandoned on that\r\n'
# b'account, I lived eight months, most tranquilly and pleasantly:\r\n'
# b'notwithstanding that the house had a score of mysterious bedrooms, which\r\n'
# b'were never used, and possessed, in one large room in which I sat reading,\r\n'
# b'times out of number at all hours, and next to which I slept, a haunted\r\n'
# b'chamber of the first pretensions.  I gently hinted these considerations\r\n'
# b'to the landlord.  And as to this particular house having a bad name, I\r\n'
# b'reasoned with him, Why, how many things had bad names undeservedly, and\r\n'
# b'how easy it was to give bad names, and did he not think that if he and I\r\n'
# b'were persistently to whisper in the village that any weird-looking, old\r\n'
# b'drunken tinker of the neighbourhood had sold himself to the Devil, he\r\n'
# b'would come in time to be suspected of that commercial venture!  All this\r\n'
# b'wise talk was perfectly ineffective with the landlord, I am bound to\r\n'
# b'confess, and was as dead a failure as ever I made in my life.\r\n'
# b'\r\n'
# b'To cut this part of the story short, I was piqued about the haunted\r\n'
# b'house, and was already half resolved to take it.  So, after breakfast, I\r\n'
# b'got the keys from Perkins\xe2\x80\x99s brother-in-law (a whip and harness maker, who\r\n'
# b'keeps the Post Office, and is under submission to a most rigorous wife of\r\n'
# b'the Doubly Seceding Little Emmanuel persuasion), and went up to the\r\n'
# b'house, attended by my landlord and by Ikey.\r\n'
# b'\r\n'
# b'Within, I found it, as I had expected, transcendently dismal.  The slowly\r\n'
# b'changing shadows waved on it from the heavy trees, were doleful in the\r\n'
# b'last degree; the house was ill-placed, ill-built, ill-planned, and\r\n'
# b'ill-fitted.  It was damp, it was not free from dry rot, there was a\r\n'
# b'flavour of rats in it, and it was the gloomy victim of that indescribable\r\n'
# b'decay which settles on all the work of man\xe2\x80\x99s hands whenever it\xe2\x80\x99s not\r\n'
# b'turned to man\xe2\x80\x99s account.  The kitchens and offices were too large, and\r\n'
# b'too remote from each other.  Above stairs and below, waste tracts of\r\n'
# b'passage intervened between patches of fertility represented by rooms; and\r\n'
# b'there was a mouldy old well with a green growth upon it, hiding like a\r\n'
# b'murderous trap, near the bottom of the back-stairs, under the double row\r\n'
# b'of bells.  One of these bells was labelled, on a black ground in faded\r\n'
# b'white letters, MASTER B.  This, they told me, was the bell that rang the\r\n'
# b'most.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWho was Master B.?\xe2\x80\x9d I asked.  \xe2\x80\x9cIs it known what he did while the owl\r\n'
# b'hooted?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cRang the bell,\xe2\x80\x9d said Ikey.\r\n'
# b'\r\n'
# b'I was rather struck by the prompt dexterity with which this young man\r\n'
# b'pitched his fur cap at the bell, and rang it himself.  It was a loud,\r\n'
# b'unpleasant bell, and made a very disagreeable sound.  The other bells\r\n'
# b'were inscribed according to the names of the rooms to which their wires\r\n'
# b'were conducted: as \xe2\x80\x9cPicture Room,\xe2\x80\x9d \xe2\x80\x9cDouble Room,\xe2\x80\x9d \xe2\x80\x9cClock Room,\xe2\x80\x9d and the\r\n'
# b'like.  Following Master B.\xe2\x80\x99s bell to its source I found that young\r\n'
# b'gentleman to have had but indifferent third-class accommodation in a\r\n'
# b'triangular cabin under the cock-loft, with a corner fireplace which\r\n'
# b'Master B. must have been exceedingly small if he were ever able to warm\r\n'
# b'himself at, and a corner chimney-piece like a pyramidal staircase to the\r\n'
# b'ceiling for Tom Thumb.  The papering of one side of the room had dropped\r\n'
# b'down bodily, with fragments of plaster adhering to it, and almost blocked\r\n'
# b'up the door.  It appeared that Master B., in his spiritual condition,\r\n'
# b'always made a point of pulling the paper down.  Neither the landlord nor\r\n'
# b'Ikey could suggest why he made such a fool of himself.\r\n'
# b'\r\n'
# b'Except that the house had an immensely large rambling loft at top, I made\r\n'
# b'no other discoveries.  It was moderately well furnished, but sparely.\r\n'
# b'Some of the furniture\xe2\x80\x94say, a third\xe2\x80\x94was as old as the house; the rest was\r\n'
# b'of various periods within the last half-century.  I was referred to a\r\n'
# b'corn-chandler in the market-place of the county town to treat for the\r\n'
# b'house.  I went that day, and I took it for six months.\r\n'
# b'\r\n'
# b'It was just the middle of October when I moved in with my maiden sister\r\n'
# b'(I venture to call her eight-and-thirty, she is so very handsome,\r\n'
# b'sensible, and engaging).  We took with us, a deaf stable-man, my\r\n'
# b'bloodhound Turk, two women servants, and a young person called an Odd\r\n'
# b'Girl.  I have reason to record of the attendant last enumerated, who was\r\n'
# b'one of the Saint Lawrence\xe2\x80\x99s Union Female Orphans, that she was a fatal\r\n'
# b'mistake and a disastrous engagement.\r\n'
# b'\r\n'
# b'The year was dying early, the leaves were falling fast, it was a raw cold\r\n'
# b'day when we took possession, and the gloom of the house was most\r\n'
# b'depressing.  The cook (an amiable woman, but of a weak turn of intellect)\r\n'
# b'burst into tears on beholding the kitchen, and requested that her silver\r\n'
# b'watch might be delivered over to her sister (2 Tuppintock\xe2\x80\x99s Gardens,\r\n'
# b'Liggs\xe2\x80\x99s Walk, Clapham Rise), in the event of anything happening to her\r\n'
# b'from the damp.  Streaker, the housemaid, feigned cheerfulness, but was\r\n'
# b'the greater martyr.  The Odd Girl, who had never been in the country,\r\n'
# b'alone was pleased, and made arrangements for sowing an acorn in the\r\n'
# b'garden outside the scullery window, and rearing an oak.\r\n'
# b'\r\n'
# b'We went, before dark, through all the natural\xe2\x80\x94as opposed to\r\n'
# b'supernatural\xe2\x80\x94miseries incidental to our state.  Dispiriting reports\r\n'
# b'ascended (like the smoke) from the basement in volumes, and descended\r\n'
# b'from the upper rooms.  There was no rolling-pin, there was no salamander\r\n'
# b'(which failed to surprise me, for I don\xe2\x80\x99t know what it is), there was\r\n'
# b'nothing in the house, what there was, was broken, the last people must\r\n'
# b'have lived like pigs, what could the meaning of the landlord be?  Through\r\n'
# b'these distresses, the Odd Girl was cheerful and exemplary.  But within\r\n'
# b'four hours after dark we had got into a supernatural groove, and the Odd\r\n'
# b'Girl had seen \xe2\x80\x9cEyes,\xe2\x80\x9d and was in hysterics.\r\n'
# b'\r\n'
# b'My sister and I had agreed to keep the haunting strictly to ourselves,\r\n'
# b'and my impression was, and still is, that I had not left Ikey, when he\r\n'
# b'helped to unload the cart, alone with the women, or any one of them, for\r\n'
# b'one minute.  Nevertheless, as I say, the Odd Girl had \xe2\x80\x9cseen Eyes\xe2\x80\x9d (no\r\n'
# b'other explanation could ever be drawn from her), before nine, and by ten\r\n'
# b'o\xe2\x80\x99clock had had as much vinegar applied to her as would pickle a handsome\r\n'
# b'salmon.\r\n'
# b'\r\n'
# b'I leave a discerning public to judge of my feelings, when, under these\r\n'
# b'untoward circumstances, at about half-past ten o\xe2\x80\x99clock Master B.\xe2\x80\x99s bell\r\n'
# b'began to ring in a most infuriated manner, and Turk howled until the\r\n'
# b'house resounded with his lamentations!\r\n'
# b'\r\n'
# b'I hope I may never again be in a state of mind so unchristian as the\r\n'
# b'mental frame in which I lived for some weeks, respecting the memory of\r\n'
# b'Master B.  Whether his bell was rung by rats, or mice, or bats, or wind,\r\n'
# b'or what other accidental vibration, or sometimes by one cause, sometimes\r\n'
# b'another, and sometimes by collusion, I don\xe2\x80\x99t know; but, certain it is,\r\n'
# b'that it did ring two nights out of three, until I conceived the happy\r\n'
# b'idea of twisting Master B.\xe2\x80\x99s neck\xe2\x80\x94in other words, breaking his bell short\r\n'
# b'off\xe2\x80\x94and silencing that young gentleman, as to my experience and belief,\r\n'
# b'for ever.\r\n'
# b'\r\n'
# b'But, by that time, the Odd Girl had developed such improving powers of\r\n'
# b'catalepsy, that she had become a shining example of that very\r\n'
# b'inconvenient disorder.  She would stiffen, like a Guy Fawkes endowed with\r\n'
# b'unreason, on the most irrelevant occasions.  I would address the servants\r\n'
# b'in a lucid manner, pointing out to them that I had painted Master B.\xe2\x80\x99s\r\n'
# b'room and balked the paper, and taken Master B.\xe2\x80\x99s bell away and balked the\r\n'
# b'ringing, and if they could suppose that that confounded boy had lived and\r\n'
# b'died, to clothe himself with no better behaviour than would most\r\n'
# b'unquestionably have brought him and the sharpest particles of a\r\n'
# b'birch-broom into close acquaintance in the present imperfect state of\r\n'
# b'existence, could they also suppose a mere poor human being, such as I\r\n'
# b'was, capable by those contemptible means of counteracting and limiting\r\n'
# b'the powers of the disembodied spirits of the dead, or of any spirits?\xe2\x80\x94I\r\n'
# b'say I would become emphatic and cogent, not to say rather complacent, in\r\n'
# b'such an address, when it would all go for nothing by reason of the Odd\r\n'
# b'Girl\xe2\x80\x99s suddenly stiffening from the toes upward, and glaring among us\r\n'
# b'like a parochial petrifaction.\r\n'
# b'\r\n'
# b'Streaker, the housemaid, too, had an attribute of a most discomfiting\r\n'
# b'nature.  I am unable to say whether she was of an unusually lymphatic\r\n'
# b'temperament, or what else was the matter with her, but this young woman\r\n'
# b'became a mere Distillery for the production of the largest and most\r\n'
# b'transparent tears I ever met with.  Combined with these characteristics,\r\n'
# b'was a peculiar tenacity of hold in those specimens, so that they didn\xe2\x80\x99t\r\n'
# b'fall, but hung upon her face and nose.  In this condition, and mildly and\r\n'
# b'deplorably shaking her head, her silence would throw me more heavily than\r\n'
# b'the Admirable Crichton could have done in a verbal disputation for a\r\n'
# b'purse of money.  Cook, likewise, always covered me with confusion as with\r\n'
# b'a garment, by neatly winding up the session with the protest that the\r\n'
# b'Ouse was wearing her out, and by meekly repeating her last wishes\r\n'
# b'regarding her silver watch.\r\n'
# b'\r\n'
# b'As to our nightly life, the contagion of suspicion and fear was among us,\r\n'
# b'and there is no such contagion under the sky.  Hooded woman?  According\r\n'
# b'to the accounts, we were in a perfect Convent of hooded women.  Noises?\r\n'
# b'With that contagion downstairs, I myself have sat in the dismal parlour,\r\n'
# b'listening, until I have heard so many and such strange noises, that they\r\n'
# b'would have chilled my blood if I had not warmed it by dashing out to make\r\n'
# b'discoveries.  Try this in bed, in the dead of the night: try this at your\r\n'
# b'own comfortable fire-side, in the life of the night.  You can fill any\r\n'
# b'house with noises, if you will, until you have a noise for every nerve in\r\n'
# b'your nervous system.\r\n'
# b'\r\n'
# b'I repeat; the contagion of suspicion and fear was among us, and there is\r\n'
# b'no such contagion under the sky.  The women (their noses in a chronic\r\n'
# b'state of excoriation from smelling-salts) were always primed and loaded\r\n'
# b'for a swoon, and ready to go off with hair-triggers.  The two elder\r\n'
# b'detached the Odd Girl on all expeditions that were considered doubly\r\n'
# b'hazardous, and she always established the reputation of such adventures\r\n'
# b'by coming back cataleptic.  If Cook or Streaker went overhead after dark,\r\n'
# b'we knew we should presently hear a bump on the ceiling; and this took\r\n'
# b'place so constantly, that it was as if a fighting man were engaged to go\r\n'
# b'about the house, administering a touch of his art which I believe is\r\n'
# b'called The Auctioneer, to every domestic he met with.\r\n'
# b'\r\n'
# b'It was in vain to do anything.  It was in vain to be frightened, for the\r\n'
# b'moment in one\xe2\x80\x99s own person, by a real owl, and then to show the owl.  It\r\n'
# b'was in vain to discover, by striking an accidental discord on the piano,\r\n'
# b'that Turk always howled at particular notes and combinations.  It was in\r\n'
# b'vain to be a Rhadamanthus with the bells, and if an unfortunate bell rang\r\n'
# b'without leave, to have it down inexorably and silence it.  It was in vain\r\n'
# b'to fire up chimneys, let torches down the well, charge furiously into\r\n'
# b'suspected rooms and recesses.  We changed servants, and it was no better.\r\n'
# b'The new set ran away, and a third set came, and it was no better.  At\r\n'
# b'last, our comfortable housekeeping got to be so disorganised and\r\n'
# b'wretched, that I one night dejectedly said to my sister: \xe2\x80\x9cPatty, I begin\r\n'
# b'to despair of our getting people to go on with us here, and I think we\r\n'
# b'must give this up.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'My sister, who is a woman of immense spirit, replied, \xe2\x80\x9cNo, John, don\xe2\x80\x99t\r\n'
# b'give it up.  Don\xe2\x80\x99t be beaten, John.  There is another way.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cAnd what is that?\xe2\x80\x9d said I.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cJohn,\xe2\x80\x9d returned my sister, \xe2\x80\x9cif we are not to be driven out of this\r\n'
# b'house, and that for no reason whatever, that is apparent to you or me, we\r\n'
# b'must help ourselves and take the house wholly and solely into our own\r\n'
# b'hands.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cBut, the servants,\xe2\x80\x9d said I.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cHave no servants,\xe2\x80\x9d said my sister, boldly.\r\n'
# b'\r\n'
# b'Like most people in my grade of life, I had never thought of the\r\n'
# b'possibility of going on without those faithful obstructions.  The notion\r\n'
# b'was so new to me when suggested, that I looked very doubtful.  \xe2\x80\x9cWe know\r\n'
# b'they come here to be frightened and infect one another, and we know they\r\n'
# b'are frightened and do infect one another,\xe2\x80\x9d said my sister.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cWith the exception of Bottles,\xe2\x80\x9d I observed, in a meditative tone.\r\n'
# b'\r\n'
# b'(The deaf stable-man.  I kept him in my service, and still keep him, as a\r\n'
# b'phenomenon of moroseness not to be matched in England.)\r\n'
# b'\r\n'
# b'\xe2\x80\x9cTo be sure, John,\xe2\x80\x9d assented my sister; \xe2\x80\x9cexcept Bottles.  And what does\r\n'
# b'that go to prove?  Bottles talks to nobody, and hears nobody unless he is\r\n'
# b'absolutely roared at, and what alarm has Bottles ever given, or taken!\r\n'
# b'None.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'This was perfectly true; the individual in question having retired, every\r\n'
# b'night at ten o\xe2\x80\x99clock, to his bed over the coach-house, with no other\r\n'
# b'company than a pitchfork and a pail of water.  That the pail of water\r\n'
# b'would have been over me, and the pitchfork through me, if I had put\r\n'
# b'myself without announcement in Bottles\xe2\x80\x99s way after that minute, I had\r\n'
# b'deposited in my own mind as a fact worth remembering.  Neither had\r\n'
# b'Bottles ever taken the least notice of any of our many uproars.  An\r\n'
# b'imperturbable and speechless man, he had sat at his supper, with Streaker\r\n'
# b'present in a swoon, and the Odd Girl marble, and had only put another\r\n'
# b'potato in his cheek, or profited by the general misery to help himself to\r\n'
# b'beefsteak pie.\r\n'
# b'\r\n'
# b'\xe2\x80\x9cAnd so,\xe2\x80\x9d continued my sister, \xe2\x80\x9cI exempt Bottles.  And considering, John,\r\n'
# b'that the house is too large, and perhaps too lonely, to be kept well in\r\n'
# b'hand by Bottles, you, and me, I propose that we cast about among our\r\n'
# b'friends for a certain selected number of the most reliable and\r\n'
# b'willing\xe2\x80\x94form a Society here for three months\xe2\x80\x94wait upon ourselves and one\r\n'
# b'another\xe2\x80\x94live cheerfully and socially\xe2\x80\x94and see what happens.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'I was so charmed with my sister, that I embraced her on the spot, and\r\n'
# b'went into her plan with the greatest ardour.\r\n'
# b'\r\n'
# b'We were then in the third week of November; but, we took our measures so\r\n'
# b'vigorously, and were so well seconded by the friends in whom we confided,\r\n'
# b'that there was still a week of the month unexpired, when our party all\r\n'
# b'came down together merrily, and mustered in the haunted house.\r\n'
# b'\r\n'
# b'I will mention, in this place, two small changes that I made while my\r\n'
# b'sister and I were yet alone.  It occurring to me as not improbable that\r\n'
# b'Turk howled in the house at night, partly because he wanted to get out of\r\n'
# b'it, I stationed him in his kennel outside, but unchained; and I seriously\r\n'
# b'warned the village that any man who came in his way must not expect to\r\n'
# b'leave him without a rip in his own throat.  I then casually asked Ikey if\r\n'
# b'he were a judge of a gun?  On his saying, \xe2\x80\x9cYes, sir, I knows a good gun\r\n'
# b'when I sees her,\xe2\x80\x9d I begged the favour of his stepping up to the house and\r\n'
# b'looking at mine.\r\n'
# b'\r\n'
# b'\xe2\x80\x9c_She\xe2\x80\x99s_ a true one, sir,\xe2\x80\x9d said Ikey, after inspecting a double-barrelled\r\n'
# b'rifle that I bought in New York a few years ago.  \xe2\x80\x9cNo mistake about\r\n'
# b'_her_, sir.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIkey,\xe2\x80\x9d said I, \xe2\x80\x9cdon\xe2\x80\x99t mention it; I have seen something in this house.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cNo, sir?\xe2\x80\x9d he whispered, greedily opening his eyes.  \xe2\x80\x9c\xe2\x80\x99Ooded lady, sir?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cDon\xe2\x80\x99t be frightened,\xe2\x80\x9d said I.  \xe2\x80\x9cIt was a figure rather like you.\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cLord, sir?\xe2\x80\x9d\r\n'
# b'\r\n'
# b'\xe2\x80\x9cIkey!\xe2\x80\x9d said I, shaking hands with him warmly: I may say affectionately;\r\n'
# b'\xe2\x80\x9cif there is any truth in these ghost-stories, the greatest service I can\r\n'
# b'do you, is, to fire at that figure.  And I promise you, by Heaven and\r\n'
# b'earth, I will do it with this gun if I see it again!\xe2\x80\x9d\r\n'
# b'\r\n'
# b'The young man thanked me, and took his leave with some little\r\n'
# b'precipitation, after declining a glass of liquor.  I imparted my secret\r\n'
# b'to him, because I had never quite forgotten his throwing his cap at the\r\n'
# b'bell; because I had, on another occasion, noticed something very like a\r\n'
# b'fur cap, lying not far from the bell, one night when it had burst out\r\n'
# b'ringing; and because I had remarked that we were at our ghostliest\r\n'
# b'whenever he came up in the evening to comfort the servants.  Let me do\r\n'
# b'Ikey no injustice.  He was afraid of the house, and believed in its being\r\n'
# b'haunted; and yet he would play false on the haunting side, so surely as\r\n'
# b'he got an opportunity.  The Odd Girl\xe2\x80\x99s case was exactly similar.  She\r\n'
# b'went about the house in a state of real terror, and yet lied monstrously\r\n'
# b'and wilfully, and invented many of the alarms she spread, and made many\r\n'
# b'of the sounds we heard.  I had had my eye on the two, and I know it.  It\r\n'
# b'is not necessary for me, here, to account for this preposterous state of\r\n'
# b'mind; I content myself with remarking that it is familiarly known to\r\n'
# b'every intelligent man who has had fair medical, legal, or other watchful\r\n'
# b'experience; that it is as well established and as common a state of mind\r\n'
# b'as any with which observers are acquainted; and that it is one of the\r\n'
# b'first elements, above all others, rationally to be suspected in, and\r\n'
# b'strictly looked for, and separated from, any question of this kind.\r\n'
# b'\r\n'
# b'To return to our party.  The first thing we did when we were all\r\n'
# b'assembled, was, to draw lots for bedrooms.  That done, and every bedroom,\r\n'
# b'and, indeed, the whole house, having been minutely examined by the whole\r\n'
# b'body, we allotted the various household duties, as if we had been on a\r\n'
# b'gipsy party, or a yachting party, or a hunting party, or were\r\n'
# b'shipwrecked.  I then recounted the floating rumours concerning the hooded\r\n'
# b'lady, the owl, and Master B.: with others, still more filmy, which had\r\n'
# b'floated about during our occupation, relative to some ridiculous old\r\n'
# b'ghost of the female gender who went up and down, carrying the ghost of a\r\n'
# b'round table; and also to an impalpable Jackass, whom nobody was ever able\r\n'
# b'to catch.  Some of these ideas I really believe our people below had\r\n'
# b'communicated to one another in some diseased way, without conveying them\r\n'
# b'in words.  We then gravely called one another to witness, that we were\r\n'
# b'not there to be deceived, or to deceive\xe2\x80\x94which we considered pretty much\r\n'
# b'the same thing\xe2\x80\x94and that, with a serious sense of responsibility, we would\r\n'
# b'be strictly true to one another, and would strictly follow out the truth.\r\n'
# b'The understanding was established, that any one who heard unusual noises\r\n'
# b'in the night, and who wished to trace them, should knock at my door;\r\n'
# b'lastly, that on Twelfth Night, the last night of holy Christmas, all our\r\n'
# b'individual experiences since that then present hour of our coming\r\n'
# b'together in the haunted house, should be brought to light for the good of\r\n'
# b'all; and that we would hold our peace on the subject till then, unless on\r\n'
# b'some remarkable provocation to break silence.\r\n'
# b'\r\n'
# b'We were, in number and in character, as follows:\r\n'
# b'\r\n'
# b'First\xe2\x80\x94to get my sister and myself out of the way\xe2\x80\x94there were we two.  In\r\n'
# b'the drawing of lots, my sister drew her own room, and I drew Master B.\xe2\x80\x99s.\r\n'
# b'Next, there was our first cousin John Herschel, so called after the great\r\n'
# b'astronomer: than whom I suppose a better man at a telescope does not\r\n'
# b'breathe.  With him, was his wife: a charming creature to whom he had been\r\n'
# b'married in the previous spring.  I thought it (under the circumstances)\r\n'
# b'rather imprudent to bring her, because there is no knowing what even a\r\n'
# b'false alarm may do at such a time; but I suppose he knew his own business\r\n'
# b'best, and I must say that if she had been _my_ wife, I never could have\r\n'
# b'left her endearing and bright face behind.  They drew the Clock Room.\r\n'
# b'Alfred Starling, an uncommonly agreeable young fellow of eight-and-twenty\r\n'
# b'for whom I have the greatest liking, was in the Double Room; mine,\r\n'
# b'usually, and designated by that name from having a dressing-room within\r\n'
# b'it, with two large and cumbersome windows, which no wedges _I_ was ever\r\n'
# b'able to make, would keep from shaking, in any weather, wind or no wind.\r\n'
# b'Alfred is a young fellow who pretends to be \xe2\x80\x9cfast\xe2\x80\x9d (another word for\r\n'
# b'loose, as I understand the term), but who is much too good and sensible\r\n'
# b'for that nonsense, and who would have distinguished himself before now,\r\n'
# b'if his father had not unfortunately left him a small independence of two\r\n'
# b'hundred a year, on the strength of which his only occupation in life has\r\n'
# b'been to spend six.  I am in hopes, however, that his Banker may break, or\r\n'
# b'that he may enter into some speculation guaranteed to pay twenty per\r\n'
# b'cent.; for, I am convinced that if he could only be ruined, his fortune\r\n'
# b'is made.  Belinda Bates, bosom friend of my sister, and a most\r\n'
# b'intellectual, amiable, and delightful girl, got the Picture Room.  She\r\n'
# b'has a fine genius for poetry, combined with real business earnestness,\r\n'
# b'and \xe2\x80\x9cgoes in\xe2\x80\x9d\xe2\x80\x94to use an expression of Alfred\xe2\x80\x99s\xe2\x80\x94for Woman\xe2\x80\x99s mission,\r\n'
# b'Woman\xe2\x80\x99s rights, Woman\xe2\x80\x99s wrongs, and everything that is woman\xe2\x80\x99s with a\r\n'
# b'capital W, or is not and ought to be, or is and ought not to be.  \xe2\x80\x9cMost\r\n'
# b'praiseworthy, my dear, and Heaven prosper you!\xe2\x80\x9d I whispered to her on the\r\n'
# b'first night of my taking leave of her at the Picture-Room door, \xe2\x80\x9cbut\r\n'
# b'don\xe2\x80\x99t overdo it.  And in respect of the great necessity there is, my\r\n'
# b'darling, for more employments being within the reach of Woman than our\r\n'
# b'civilisation has as yet assigned to her, don\xe2\x80\x99t fly at the unfortunate\r\n'
# b'men, even those men who are at first sight in your way, as if they were\r\n'
# b'the natural oppressors of your sex; for, trust me, Belinda, they do\r\n'
# b'sometimes spend their wages among wives and daughters, sisters, mothers,\r\n'
# b'aunts, and grandmothers; and the play is, really, not _all_ Wolf and Red\r\n'
# b'Riding-Hood, but has other parts in it.\xe2\x80\x9d  However, I digress.\r\n'
# b'\r\n'
# b'Belinda, as I have mentioned, occupied the Picture Room.  We had but\r\n'
# b'three other chambers: the Corner Room, the Cupboard Room, and the Garden\r\n'
# b'Room.  My old friend, Jack Governor, \xe2\x80\x9cslung his hammock,\xe2\x80\x9d as he called\r\n'
# b'it, in the Corner Room.  I have always regarded Jack as the\r\n'
# b'finest-looking sailor that ever sailed.  He is gray now, but as handsome\r\n'
# b'as he was a quarter of a century ago\xe2\x80\x94nay, handsomer.  A portly, cheery,\r\n'
# b'well-built figure of a broad-shouldered man, with a frank smile, a\r\n'
# b'brilliant dark eye, and a rich dark eyebrow.  I remember those under\r\n'
# b'darker hair, and they look all the better for their silver setting.  He\r\n'
# b'has been wherever his Union namesake flies, has Jack, and I have met old\r\n'
# b'shipmates of his, away in the Mediterranean and on the other side of the\r\n'
# b'Atlantic, who have beamed and brightened at the casual mention of his\r\n'
# b'name, and have cried, \xe2\x80\x9cYou know Jack Governor?  Then you know a prince of\r\n'
# b'men!\xe2\x80\x9d  That he is!  And so unmistakably a naval officer, that if you were\r\n'
# b'to meet him coming out of an Esquimaux snow-hut in seal\xe2\x80\x99s skin, you would\r\n'
# b'be vaguely persuaded he was in full naval uniform.\r\n'
# b'\r\n'
# b'Jack once had that bright clear eye of his on my sister; but, it fell out\r\n'
# b'that he married another lady and took her to South America, where she\r\n'
# b'died.  This was a dozen years ago or more.  He brought down with him to\r\n'
# b'our haunted house a little cask of salt beef; for, he is always convinced\r\n'
# b'that all salt beef not of his own pickling, is mere carrion, and\r\n'
# b'invariably, when he goes to London, packs a piece in his portmanteau.  He\r\n'
# b'had also volunteered to bring with him one \xe2\x80\x9cNat Beaver,\xe2\x80\x9d an old comrade\r\n'
# b'of his, captain of a merchantman.  Mr. Beaver, with a thick-set wooden\r\n'
# b'face and figure, and apparently as hard as a block all over, proved to be\r\n'
# b'an intelligent man, with a world of watery experiences in him, and great\r\n'
# b'practical knowledge.  At times, there was a curious nervousness about\r\n'
# b'him, apparently the lingering result of some old illness; but, it seldom\r\n'
# b'lasted many minutes.  He got the Cupboard Room, and lay there next to Mr.\r\n'
# b'Undery, my friend and solicitor: who came down, in an amateur capacity,\r\n'
# b'\xe2\x80\x9cto go through with it,\xe2\x80\x9d as he said, and who plays whist better than the\r\n'
# b'whole Law List, from the red cover at the beginning to the red cover at\r\n'
# b'the end.\r\n'
# b'\r\n'
# b'I never was happier in my life, and I believe it was the universal\r\n'
# b'feeling among us.  Jack Governor, always a man of wonderful resources,\r\n'
# b'was Chief Cook, and made some of the best dishes I ever ate, including\r\n'
# b'unapproachable curries.  My sister was pastrycook and confectioner.\r\n'
# b'Starling and I were Cook\xe2\x80\x99s Mate, turn and turn about, and on special\r\n'
# b'occasions the chief cook \xe2\x80\x9cpressed\xe2\x80\x9d Mr. Beaver.  We had a great deal of\r\n'
# b'out-door sport and exercise, but nothing was neglected within, and there\r\n'
# b'was no ill-humour or misunderstanding among us, and our evenings were so\r\n'
# b'delightful that we had at least one good reason for being reluctant to go\r\n'
# b'to bed.\r\n'
# b'\r\n'
# b'We had a few night alarms in the beginning.  On the first night, I was\r\n'
# b'knocked up by Jack with a most wonderful ship\xe2\x80\x99s lantern in his hand, like\r\n'
# b'the gills of some monster of the deep, who informed me that he \xe2\x80\x9cwas going\r\n'
# b'aloft to the main truck,\xe2\x80\x9d to have the weathercock down.  It was a stormy\r\n'
# b'night and I remonstrated; but Jack called my attention to its making a\r\n'
# b'sound like a cry of despair, and said somebody would be \xe2\x80\x9chailing a ghost\xe2\x80\x9d\r\n'
# b'presently, if it wasn\xe2\x80\x99t done.  So, up to the top of the house, where I\r\n'
# ...
# b'Gutenberg-tm work.  The Foundation makes no representations concerning\r\n'
# b'the copyright status of any work in any country outside the United\r\n'
# b'States.\r\n'
# b'\r\n'
# b'1.E.  Unless you have removed all references to Project Gutenberg:\r\n'
# b'\r\n'
# b'1.E.1.  The following sentence, with active links to, or other immediate\r\n'
# b'access to, the full Project Gutenberg-tm License must appear prominently\r\n'
# b'whenever any copy of a Project Gutenberg-tm work (any work on which the\r\n'
# b'phrase "Project Gutenberg" appears, or with which the phrase "Project\r\n'
# b'Gutenberg" is associated) is accessed, displayed, performed, viewed,\r\n'
# b'copied or distributed:\r\n'
# b'\r\n'
# b'This eBook is for the use of anyone anywhere at no cost and with\r\n'
# b'almost no restrictions whatsoever.  You may copy it, give it away or\r\n'
# b're-use it under the terms of the Project Gutenberg License included\r\n'
# b'with this eBook or online at www.gutenberg.org\r\n'
# b'\r\n'
# b'1.E.2.  If an individual Project Gutenberg-tm electronic work is derived\r\n'
# b'from the public domain (does not contain a notice indicating that it is\r\n'
# b'posted with permission of the copyright holder), the work can be copied\r\n'
# b'and distributed to anyone in the United States without paying any fees\r\n'
# b'or charges.  If you are redistributing or providing access to a work\r\n'
# b'with the phrase "Project Gutenberg" associated with or appearing on the\r\n'
# b'work, you must comply either with the requirements of paragraphs 1.E.1\r\n'
# b'through 1.E.7 or obtain permission for the use of the work and the\r\n'
# b'Project Gutenberg-tm trademark as set forth in paragraphs 1.E.8 or\r\n'
# b'1.E.9.\r\n'
# b'\r\n'
# b'1.E.3.  If an individual Project Gutenberg-tm electronic work is posted\r\n'
# b'with the permission of the copyright holder, your use and distribution\r\n'
# b'must comply with both paragraphs 1.E.1 through 1.E.7 and any additional\r\n'
# b'terms imposed by the copyright holder.  Additional terms will be linked\r\n'
# b'to the Project Gutenberg-tm License for all works posted with the\r\n'
# b'permission of the copyright holder found at the beginning of this work.\r\n'
# b'\r\n'
# b'1.E.4.  Do not unlink or detach or remove the full Project Gutenberg-tm\r\n'
# b'License terms from this work, or any files containing a part of this\r\n'
# b'work or any other work associated with Project Gutenberg-tm.\r\n'
# b'\r\n'
# b'1.E.5.  Do not copy, display, perform, distribute or redistribute this\r\n'
# b'electronic work, or any part of this electronic work, without\r\n'
# b'prominently displaying the sentence set forth in paragraph 1.E.1 with\r\n'
# b'active links or immediate access to the full terms of the Project\r\n'
# b'Gutenberg-tm License.\r\n'
# b'\r\n'
# b'1.E.6.  You may convert to and distribute this work in any binary,\r\n'
# b'compressed, marked up, nonproprietary or proprietary form, including any\r\n'
# b'word processing or hypertext form.  However, if you provide access to or\r\n'
# b'distribute copies of a Project Gutenberg-tm work in a format other than\r\n'
# b'"Plain Vanilla ASCII" or other format used in the official version\r\n'
# b'posted on the official Project Gutenberg-tm web site (www.gutenberg.org),\r\n'
# b'you must, at no additional cost, fee or expense to the user, provide a\r\n'
# b'copy, a means of exporting a copy, or a means of obtaining a copy upon\r\n'
# b'request, of the work in its original "Plain Vanilla ASCII" or other\r\n'
# b'form.  Any alternate format must include the full Project Gutenberg-tm\r\n'
# b'License as specified in paragraph 1.E.1.\r\n'
# b'\r\n'
# b'1.E.7.  Do not charge a fee for access to, viewing, displaying,\r\n'
# b'performing, copying or distributing any Project Gutenberg-tm works\r\n'
# b'unless you comply with paragraph 1.E.8 or 1.E.9.\r\n'
# b'\r\n'
# b'1.E.8.  You may charge a reasonable fee for copies of or providing\r\n'
# b'access to or distributing Project Gutenberg-tm electronic works provided\r\n'
# b'that\r\n'
# b'\r\n'
# b'- You pay a royalty fee of 20% of the gross profits you derive from\r\n'
# b'     the use of Project Gutenberg-tm works calculated using the method\r\n'
# b'     you already use to calculate your applicable taxes.  The fee is\r\n'
# b'     owed to the owner of the Project Gutenberg-tm trademark, but he\r\n'
# b'     has agreed to donate royalties under this paragraph to the\r\n'
# b'     Project Gutenberg Literary Archive Foundation.  Royalty payments\r\n'
# b'     must be paid within 60 days following each date on which you\r\n'
# b'     prepare (or are legally required to prepare) your periodic tax\r\n'
# b'     returns.  Royalty payments should be clearly marked as such and\r\n'
# b'     sent to the Project Gutenberg Literary Archive Foundation at the\r\n'
# b'     address specified in Section 4, "Information about donations to\r\n'
# b'     the Project Gutenberg Literary Archive Foundation."\r\n'
# b'\r\n'
# b'- You provide a full refund of any money paid by a user who notifies\r\n'
# b'     you in writing (or by e-mail) within 30 days of receipt that s/he\r\n'
# b'     does not agree to the terms of the full Project Gutenberg-tm\r\n'
# b'     License.  You must require such a user to return or\r\n'
# b'     destroy all copies of the works possessed in a physical medium\r\n'
# b'     and discontinue all use of and all access to other copies of\r\n'
# b'     Project Gutenberg-tm works.\r\n'
# b'\r\n'
# b'- You provide, in accordance with paragraph 1.F.3, a full refund of any\r\n'
# b'     money paid for a work or a replacement copy, if a defect in the\r\n'
# b'     electronic work is discovered and reported to you within 90 days\r\n'
# b'     of receipt of the work.\r\n'
# b'\r\n'
# b'- You comply with all other terms of this agreement for free\r\n'
# b'     distribution of Project Gutenberg-tm works.\r\n'
# b'\r\n'
# b'1.E.9.  If you wish to charge a fee or distribute a Project Gutenberg-tm\r\n'
# b'electronic work or group of works on different terms than are set\r\n'
# b'forth in this agreement, you must obtain permission in writing from\r\n'
# b'both the Project Gutenberg Literary Archive Foundation and Michael\r\n'
# b'Hart, the owner of the Project Gutenberg-tm trademark.  Contact the\r\n'
# b'Foundation as set forth in Section 3 below.\r\n'
# b'\r\n'
# b'1.F.\r\n'
# b'\r\n'
# b'1.F.1.  Project Gutenberg volunteers and employees expend considerable\r\n'
# b'effort to identify, do copyright research on, transcribe and proofread\r\n'
# b'public domain works in creating the Project Gutenberg-tm\r\n'
# b'collection.  Despite these efforts, Project Gutenberg-tm electronic\r\n'
# b'works, and the medium on which they may be stored, may contain\r\n'
# b'"Defects," such as, but not limited to, incomplete, inaccurate or\r\n'
# b'corrupt data, transcription errors, a copyright or other intellectual\r\n'
# b'property infringement, a defective or damaged disk or other medium, a\r\n'
# b'computer virus, or computer codes that damage or cannot be read by\r\n'
# b'your equipment.\r\n'
# b'\r\n'
# b'1.F.2.  LIMITED WARRANTY, DISCLAIMER OF DAMAGES - Except for the "Right\r\n'
# b'of Replacement or Refund" described in paragraph 1.F.3, the Project\r\n'
# b'Gutenberg Literary Archive Foundation, the owner of the Project\r\n'
# b'Gutenberg-tm trademark, and any other party distributing a Project\r\n'
# b'Gutenberg-tm electronic work under this agreement, disclaim all\r\n'
# b'liability to you for damages, costs and expenses, including legal\r\n'
# b'fees.  YOU AGREE THAT YOU HAVE NO REMEDIES FOR NEGLIGENCE, STRICT\r\n'
# b'LIABILITY, BREACH OF WARRANTY OR BREACH OF CONTRACT EXCEPT THOSE\r\n'
# b'PROVIDED IN PARAGRAPH 1.F.3.  YOU AGREE THAT THE FOUNDATION, THE\r\n'
# b'TRADEMARK OWNER, AND ANY DISTRIBUTOR UNDER THIS AGREEMENT WILL NOT BE\r\n'
# b'LIABLE TO YOU FOR ACTUAL, DIRECT, INDIRECT, CONSEQUENTIAL, PUNITIVE OR\r\n'
# b'INCIDENTAL DAMAGES EVEN IF YOU GIVE NOTICE OF THE POSSIBILITY OF SUCH\r\n'
# b'DAMAGE.\r\n'
# b'\r\n'
# b'1.F.3.  LIMITED RIGHT OF REPLACEMENT OR REFUND - If you discover a\r\n'
# b'defect in this electronic work within 90 days of receiving it, you can\r\n'
# b'receive a refund of the money (if any) you paid for it by sending a\r\n'
# b'written explanation to the person you received the work from.  If you\r\n'
# b'received the work on a physical medium, you must return the medium with\r\n'
# b'your written explanation.  The person or entity that provided you with\r\n'
# b'the defective work may elect to provide a replacement copy in lieu of a\r\n'
# b'refund.  If you received the work electronically, the person or entity\r\n'
# b'providing it to you may choose to give you a second opportunity to\r\n'
# b'receive the work electronically in lieu of a refund.  If the second copy\r\n'
# b'is also defective, you may demand a refund in writing without further\r\n'
# b'opportunities to fix the problem.\r\n'
# b'\r\n'
# b'1.F.4.  Except for the limited right of replacement or refund set forth\r\n'
# b"in paragraph 1.F.3, this work is provided to you 'AS-IS', WITH NO OTHER\r\n"
# b'WARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO\r\n'
# b'WARRANTIES OF MERCHANTABILITY OR FITNESS FOR ANY PURPOSE.\r\n'
# b'\r\n'
# b'1.F.5.  Some states do not allow disclaimers of certain implied\r\n'
# b'warranties or the exclusion or limitation of certain types of damages.\r\n'
# b'If any disclaimer or limitation set forth in this agreement violates the\r\n'
# b'law of the state applicable to this agreement, the agreement shall be\r\n'
# b'interpreted to make the maximum disclaimer or limitation permitted by\r\n'
# b'the applicable state law.  The invalidity or unenforceability of any\r\n'
# b'provision of this agreement shall not void the remaining provisions.\r\n'
# b'\r\n'
# b'1.F.6.  INDEMNITY - You agree to indemnify and hold the Foundation, the\r\n'
# b'trademark owner, any agent or employee of the Foundation, anyone\r\n'
# b'providing copies of Project Gutenberg-tm electronic works in accordance\r\n'
# b'with this agreement, and any volunteers associated with the production,\r\n'
# b'promotion and distribution of Project Gutenberg-tm electronic works,\r\n'
# b'harmless from all liability, costs and expenses, including legal fees,\r\n'
# b'that arise directly or indirectly from any of the following which you do\r\n'
# b'or cause to occur: (a) distribution of this or any Project Gutenberg-tm\r\n'
# b'work, (b) alteration, modification, or additions or deletions to any\r\n'
# b'Project Gutenberg-tm work, and (c) any Defect you cause.\r\n'
# b'\r\n'
# b'\r\n'
# b'Section  2.  Information about the Mission of Project Gutenberg-tm\r\n'
# b'\r\n'
# b'Project Gutenberg-tm is synonymous with the free distribution of\r\n'
# b'electronic works in formats readable by the widest variety of computers\r\n'
# b'including obsolete, old, middle-aged and new computers.  It exists\r\n'
# b'because of the efforts of hundreds of volunteers and donations from\r\n'
# b'people in all walks of life.\r\n'
# b'\r\n'
# b'Volunteers and financial support to provide volunteers with the\r\n'
# b"assistance they need are critical to reaching Project Gutenberg-tm's\r\n"
# b'goals and ensuring that the Project Gutenberg-tm collection will\r\n'
# b'remain freely available for generations to come.  In 2001, the Project\r\n'
# b'Gutenberg Literary Archive Foundation was created to provide a secure\r\n'
# b'and permanent future for Project Gutenberg-tm and future generations.\r\n'
# b'To learn more about the Project Gutenberg Literary Archive Foundation\r\n'
# b'and how your efforts and donations can help, see Sections 3 and 4\r\n'
# b'and the Foundation information page at www.gutenberg.org\r\n'
# b'\r\n'
# b'\r\n'
# b'Section 3.  Information about the Project Gutenberg Literary Archive\r\n'
# b'Foundation\r\n'
# b'\r\n'
# b'The Project Gutenberg Literary Archive Foundation is a non profit\r\n'
# b'501(c)(3) educational corporation organized under the laws of the\r\n'
# b'state of Mississippi and granted tax exempt status by the Internal\r\n'
# b"Revenue Service.  The Foundation's EIN or federal tax identification\r\n"
# b'number is 64-6221541.  Contributions to the Project Gutenberg\r\n'
# b'Literary Archive Foundation are tax deductible to the full extent\r\n'
# b"permitted by U.S. federal laws and your state's laws.\r\n"
# b'\r\n'
# b"The Foundation's principal office is located at 4557 Melan Dr. S.\r\n"
# b'Fairbanks, AK, 99712., but its volunteers and employees are scattered\r\n'
# b'throughout numerous locations.  Its business office is located at 809\r\n'
# b'North 1500 West, Salt Lake City, UT 84116, (801) 596-1887.  Email\r\n'
# b'contact links and up to date contact information can be found at the\r\n'
# b"Foundation's web site and official page at www.gutenberg.org/contact\r\n"
# b'\r\n'
# b'For additional contact information:\r\n'
# b'     Dr. Gregory B. Newby\r\n'
# b'     Chief Executive and Director\r\n'
# b'     gbnewby@pglaf.org\r\n'
# b'\r\n'
# b'Section 4.  Information about Donations to the Project Gutenberg\r\n'
# b'Literary Archive Foundation\r\n'
# b'\r\n'
# b'Project Gutenberg-tm depends upon and cannot survive without wide\r\n'
# b'spread public support and donations to carry out its mission of\r\n'
# b'increasing the number of public domain and licensed works that can be\r\n'
# b'freely distributed in machine readable form accessible by the widest\r\n'
# b'array of equipment including outdated equipment.  Many small donations\r\n'
# b'($1 to $5,000) are particularly important to maintaining tax exempt\r\n'
# b'status with the IRS.\r\n'
# b'\r\n'
# b'The Foundation is committed to complying with the laws regulating\r\n'
# b'charities and charitable donations in all 50 states of the United\r\n'
# b'States.  Compliance requirements are not uniform and it takes a\r\n'
# b'considerable effort, much paperwork and many fees to meet and keep up\r\n'
# b'with these requirements.  We do not solicit donations in locations\r\n'
# b'where we have not received written confirmation of compliance.  To\r\n'
# b'SEND DONATIONS or determine the status of compliance for any\r\n'
# b'particular state visit www.gutenberg.org/donate\r\n'
# b'\r\n'
# b'While we cannot and do not solicit contributions from states where we\r\n'
# b'have not met the solicitation requirements, we know of no prohibition\r\n'
# b'against accepting unsolicited donations from donors in such states who\r\n'
# b'approach us with offers to donate.\r\n'
# b'\r\n'
# b'International donations are gratefully accepted, but we cannot make\r\n'
# b'any statements concerning tax treatment of donations received from\r\n'
# b'outside the United States.  U.S. laws alone swamp our small staff.\r\n'
# b'\r\n'
# b'Please check the Project Gutenberg Web pages for current donation\r\n'
# b'methods and addresses.  Donations are accepted in a number of other\r\n'
# b'ways including checks, online payments and credit card donations.\r\n'
# b'To donate, please visit:  www.gutenberg.org/donate\r\n'
# b'\r\n'
# b'\r\n'
# b'Section 5.  General Information About Project Gutenberg-tm electronic\r\n'
# b'works.\r\n'
# b'\r\n'
# b'Professor Michael S. Hart was the originator of the Project Gutenberg-tm\r\n'
# b'concept of a library of electronic works that could be freely shared\r\n'
# b'with anyone.  For forty years, he produced and distributed Project\r\n'
# b'Gutenberg-tm eBooks with only a loose network of volunteer support.\r\n'
# b'\r\n'
# b'Project Gutenberg-tm eBooks are often created from several printed\r\n'
# b'editions, all of which are confirmed as Public Domain in the U.S.\r\n'
# b'unless a copyright notice is included.  Thus, we do not necessarily\r\n'
# b'keep eBooks in compliance with any particular paper edition.\r\n'
# b'\r\n'
# b'Most people start at our Web site which has the main PG search facility:\r\n'
# b'\r\n'
# b'     www.gutenberg.org\r\n'
# b'\r\n'
# b'This Web site includes information about Project Gutenberg-tm,\r\n'
# b'including how to make donations to the Project Gutenberg Literary\r\n'
# b'Archive Foundation, how to help produce our new eBooks, and how to\r\n'
# b'subscribe to our email newsletter to hear about new eBooks.\r\n'
# 115
# 117
# 98
# 115
# 99
# 114
# 105
# 98
# 101
# 32
# 116
# 111
# 32
# 111
# 117
# 114
# 32
# 101
# 109
# 97
# 105
# 108
# 32
# 110
# 101
# 119
# 115
# 108
# 101
# 116
# 116
# 101
# 114
# 32
# 116
# 111
# 32
# 104
# 101
# 97
# 114
# 32
# 97
# 98
# 111
# 117
# 116
# 32
# 110
# 101
# 119
# 32
# 101
# 66
# 111
# 111
# 107
# 115
# 46
# 13
# 10

# %%
import pandas as pd

ded = pd.DataFrame({'strings': ['a#bc1!', 'a(b$c']})
type(ded)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Question 7
#
# * Write a python function `CountWords` that takes the URL for a text and returns the number of unique words within the text.
# * Write a python function `Top20Words` that takes the URL for a text and returns the most frequently appearing top 20 words within the text.

# %% [markdown]
# # Question 8
#
# * Pull the [IMKB](https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx) data from UCI using pandas.
# * Plot the TL based ISE and USD based ISE columns together in the same graph.
# * Calculate how many times `NIKKEI` was higher than `FTSE`.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel (r'https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx', header = 1)
ISE_TL = df["ISE"]
ISE_USD = df["ISE.1"]
plt.plot(ISE_TL,ISE_USD)
plt.show()

count = 0
for i in range(len(ISE_TL)):
    if df["NIKKEI"][i] - df["FTSE"][i] > 0:
        count +=1
    else:
        pass

print("{} times NIKKEI was higher than FTSE".format(count))
# Out:
# 261 times NIKKEI was higher than FTSE

# %% [markdown]
# # Question 9
#
# Using the [networkx](https://networkx.org/) library
#
# * Get the [adjacency matrix](https://en.wikipedia.org/wiki/Adjacency_matrix) of the [Peterson graph](https://en.wikipedia.org/wiki/Petersen_graph).
# * Calculate its eigen-values and eigen-vectors using the [numpy](https://numpy.org/) library.
# * Repeat the same for a [random 3-regular graph on 10 vertices](https://networkx.org/documentation/networkx-1.10/reference/generated/networkx.generators.random_graphs.random_regular_graph.html).

# %%
import networkx as nx
from numpy import linalg as LA

PG = nx.petersen_graph()
adj_PG = nx.adjacency_matrix(PG)
w, v = LA.eig(adj_PG)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-69-ace52e221507> in <module>()
#       4 PG = nx.petersen_graph()
#       5 adj_PG = nx.adjacency_matrix(PG)
# ----> 6 w, v = LA.eig(adj_PG)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1301     """
#    1302     a, wrap = _makearray(a)
# -> 1303     _assertRankAtLeast2(a)
#    1304     _assertNdSquareness(a)
#    1305     _assertFinite(a)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertRankAtLeast2(*arrays)
#     205         if a.ndim < 2:
#     206             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 207                     'at least two-dimensional' % a.ndim)
#     208
#     209 def _assertNdSquareness(*arrays):
#
# LinAlgError: 0-dimensional array given. Array must be at least two-dimensional

# %%
import networkx as nx
from numpy import linalg as LA

PG = nx.petersen_graph()
PG_adj = PG.adjacency()
PG_adj
w, v = LA.eig(PG_adj)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-76-3ebe2dc4005b> in <module>()
#       5 PG_adj = PG.adjacency()
#       6 PG_adj
# ----> 7 w, v = LA.eig(PG_adj)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1301     """
#    1302     a, wrap = _makearray(a)
# -> 1303     _assertRankAtLeast2(a)
#    1304     _assertNdSquareness(a)
#    1305     _assertFinite(a)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertRankAtLeast2(*arrays)
#     205         if a.ndim < 2:
#     206             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 207                     'at least two-dimensional' % a.ndim)
#     208
#     209 def _assertNdSquareness(*arrays):
#
# LinAlgError: 0-dimensional array given. Array must be at least two-dimensional

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA

Graph = nx.petersen_graph()
nx.draw_shell(Graph, nlist=[range(5, 10), range(5)],  font_weight='bold',node_color=range(10),cmap=plt.cm.Blues,font_color='r',style='dotted')
plt.show()

A=np.array(nx.adjacency_matrix(Graph).todense())
w, v = LA.eig(A)
